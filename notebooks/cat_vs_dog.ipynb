# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Could not find kaggle.json. Make sure it's located in /home/moeenuddin/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
